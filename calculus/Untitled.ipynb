# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *
# %matplotlib notebook

# %%
f = lambda x: sum([sin(x / d) for d in range(1, 4)])

xs = np.linspace(0, 8.674)
ys = [f(x) for x in xs]

# %%
plt.plot(xs, ys)
# Out:
# <img src="data:image/png;base64,..." width="640">
