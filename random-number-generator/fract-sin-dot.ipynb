# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
xs = np.linspace(0, 1)
ys = np.sin(2 * pi * 1 * xs)

plot(xs, ys, 'bo')

# %%
step = 0.1

def distrib(frequency, amplitude):
    xs = np.linspace(0, 1, int(1 / step))
    ys = (np.sin(xs * 2 * pi * frequency) * amplitude) % 1.0
    scatter(xs, ys)
    return ()

interact(distrib, frequency=(0, 100, 0.1), amplitude=(0, 100, 0.1))
show()
# Out:
# interactive(children=(FloatSlider(value=50.0, description='frequency'), FloatSlider(value=50.0, description='a…

# %%
def random(xs):
    freq = 123.456
    ampl = 789.123
    return np.sin(xs * freq) * ampl % 1.0

def interp

xs = np.linspace(0, 10, 10)
ys = random(xs)

plt.scatter(xs, ys)

# %%
def intRandom(x):
    x = (x << 13) ^ x
    a = 1
    b = 0
    c = 0
    return ( 1.0 - ( (x * (x * x * a + b) + c) & 0x7fffffff) / 1073741824.0);

# %%
xs = list(range(10))
ys = [intRandom(x) for x in xs]

plt.scatter(xs, ys)
